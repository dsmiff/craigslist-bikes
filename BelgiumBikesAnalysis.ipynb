# %%
import os
import sys
import json
import requests
import re
import argparse
from pprint import pprint
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
import unicodedata
import math

# %%
class Item(object):
    def __init__(self, price, location, datetime):
        self.price = price
        self.location = location
        self.datetime = datetime

# %%
def convert_to_int(price_str):
    print 'price to be converted: ', price_str
    price_str = re.search(r'\d+', price_str)
    try:
        return int(price_str.group())
    except Exception:
        return -9999

# %%
def convert_to_string(item):
    return unicodedata.normalize('NFKD',item).encode('ascii', 'ignore')

# %%
# let's convert these into graceful functions
def get_price(item):
    try:
        price = item.find('div', {'class':'listed-item-price'}).get_text()
    except Exception:
        return None
    
    price = convert_to_int(convert_to_string(price))
    return price

def get_location(item):
    try:
        location = item.find('address',{'class':'listed-item-place'}).get_text()
    except Exception:
        return None
    
    location = convert_to_string(location)
    return location.strip()

def get_date(item):
    try:
        date = item.find('time',{'class':'listed-item-date'}).get_text()
    except Exception:
        return None
    date = convert_to_string(date)
    return date.strip()

# %%
def parse_item(item):    
    item = Item(get_price(item), get_location(item), get_date(item))
    return item

# %%
# these are results from the 1st page - we would like results from all X pages
parsed_items = []
offset_jump = 35
for i in range(0, 10):
    offset = int(offset_jump*i)
    url_path = "https://www.2ememain.be/v%C3%A9los/v%C3%A9los/2/velo/?offset={}".format(offset)
    raw = requests.get(url_path).text
    soup = BeautifulSoup(raw,'lxml')
    
    items = soup.findAll('article')
    for item in items:
        parsed_items.append(parse_item(item))
    time.sleep(5)
# Out:
# price to be converted:   56,99
# price to be converted:   400,00
# price to be converted:  Ne s'applique pas
# price to be converted:  Prix a disc.
# price to be converted:   400,00
# price to be converted:  Prix a disc.
# price to be converted:   5,00
# price to be converted:   25,00
# price to be converted:   195,00
# price to be converted:   70,00
# price to be converted:   280,00
# price to be converted:   125,00
# price to be converted:   1.950,00
# price to be converted:   15,00
# price to be converted:   10,00
# price to be converted:   95,00
# price to be converted:   30,00
# price to be converted:   79,00
# price to be converted:   275,00
# price to be converted:   20,00
# price to be converted:   100,00
# price to be converted:   60,00
# price to be converted:  Prix a disc.
# price to be converted:   200,00
# price to be converted:   550,00
# price to be converted:  Prix a disc.
# price to be converted:  Prix a disc.
# price to be converted:   50,00
# price to be converted:   20,00
# price to be converted:   200,00
# price to be converted:   1.500,00
# price to be converted:   150,00
# price to be converted:   400,00
# price to be converted:   95,00
# price to be converted:   130,00
# price to be converted:   100,00
# price to be converted:   90,00
# price to be converted:  Prix a disc.
# price to be converted:   1.650,00
# price to be converted:  Ne s'applique pas
# price to be converted:   4.900,00
# price to be converted:   495,00
# price to be converted:   90,00
# price to be converted:   100,00
# price to be converted:  Prix a disc.
# price to be converted:   550,00
# price to be converted:   35,00
# price to be converted:   150,00
# price to be converted:   650,00
# price to be converted:   625,00
# price to be converted:   200,00
# price to be converted:   700,00
# price to be converted:   200,00
# price to be converted:   20,00
# price to be converted:   170,00
# price to be converted:   75,00
# price to be converted:   165,00
# price to be converted:   90,00
# price to be converted:   80,00
# price to be converted:   170,00
# price to be converted:   140,00
# price to be converted:   40,00
# price to be converted:   15,00
# price to be converted:   125,00
# price to be converted:   90,00
# price to be converted:   20,00
# price to be converted:  Prix a disc.
# price to be converted:   90,00
# price to be converted:   300,00
# price to be converted:   230,00
# price to be converted:   75,00
# price to be converted:   70,00
# price to be converted:   13,00
# price to be converted:   350,00
# price to be converted:   100,00
# price to be converted:   2.999,00
# price to be converted:  Ne s'applique pas
# price to be converted:   1.650,00
# price to be converted:   4.900,00
# price to be converted:   130,00
# price to be converted:   1.200,00
# price to be converted:   580,00
# price to be converted:   2.650,00
# price to be converted:   35,00
# price to be converted:   35,00
# price to be converted:   10,00
# price to be converted:   40,00
# price to be converted:   25,00
# price to be converted:   60,00
# price to be converted:   130,00
# price to be converted:   20,00
# price to be converted:   70,00
# price to be converted:   70,00
# price to be converted:   50,00
# price to be converted:   150,00
# price to be converted:   160,00
# price to be converted:   20,00
# price to be converted:   1.250,00
# price to be converted:   600,00
# price to be converted:   160,00
# price to be converted:   25,00
# price to be converted:   25,00
# price to be converted:  Prix a disc.
# price to be converted:   20,00
# price to be converted:   70,00
# price to be converted:   80,00
# price to be converted:   80,00
# price to be converted:   35,00
# price to be converted:   90,00
# price to be converted:   110,00
# price to be converted:   85,00
# price to be converted:   75,00
# price to be converted:   25,00
# price to be converted:   100,00
# price to be converted:   4.900,00
# price to be converted:  Ne s'applique pas
# price to be converted:   400,00
# price to be converted:   25,00
# price to be converted:   40,00
# price to be converted:   500,00
# price to be converted:   40,00
# price to be converted:   239,00
# price to be converted:   45,00
# price to be converted:   75,00
# price to be converted:   75,00
# price to be converted:   80,00
# price to be converted:   120,00
# price to be converted:   600,00
# price to be converted:   800,00
# price to be converted:   900,00
# price to be converted:  Prix a disc.
# price to be converted:   25,00
# price to be converted:  Prix a disc.
# price to be converted:   80,00
# price to be converted:   50,00
# price to be converted:   160,00
# price to be converted:   2.100,00
# price to be converted:   450,00
# price to be converted:   400,00
# price to be converted:   40,00
# price to be converted:  Prix a disc.
# price to be converted:   30,00
# price to be converted:   140,00
# price to be converted:   20,00
# price to be converted:   200,00
# price to be converted:   800,00
# price to be converted:   250,00
# price to be converted:   3.400,00
# price to be converted:   3.400,00
# price to be converted:   28,00
# price to be converted:   85,00
# price to be converted:   270,00
# price to be converted:   10,00
# price to be converted:   369,00
# price to be converted:   1.650,00
# price to be converted:  Prix a disc.
# price to be converted:  Prix a disc.
# price to be converted:   370,00
# price to be converted:   950,00
# price to be converted:  Prix a disc.
# price to be converted:   35,00
# price to be converted:  Prix a disc.
# price to be converted:   20,00
# price to be converted:   50,00
# price to be converted:   50,00
# price to be converted:   100,00
# price to be converted:  Prix a disc.
# price to be converted:  Prix a disc.
# price to be converted:   100,00
# price to be converted:   300,00
# price to be converted:   150,00
# price to be converted:   45,00
# price to be converted:   20,00
# price to be converted:   20,00
# price to be converted:  Prix a disc.
# price to be converted:   50,00
# price to be converted:  Prix a disc.
# price to be converted:  Prix a disc.
# price to be converted:   70,00
# price to be converted:   170,00
# price to be converted:   500,00
# price to be converted:   699,00
# price to be converted:   80,00
# price to be converted:   70,00
# price to be converted:   70,00
# price to be converted:   850,00
# price to be converted:  Prix a disc.
# price to be converted:  Prix a disc.
# price to be converted:   80,00
# price to be converted:   50,00
# price to be converted:   1.650,00
# price to be converted:   10,00
# price to be converted:  Ne s'applique pas
# price to be converted:   75,00
# price to be converted:   40,00
# price to be converted:   70,00
# price to be converted:   30,00
# price to be converted:   70,00
# price to be converted:   60,00
# price to be converted:   70,00
# price to be converted:   250,00
# price to be converted:   20,00
# price to be converted:   1.100,00
# price to be converted:  Prix a disc.
# price to be converted:   120,00
# price to be converted:   75,00
# price to be converted:   90,00
# price to be converted:   80,00
# price to be converted:   80,00
# price to be converted:   120,00
# price to be converted:   250,00
# price to be converted:   300,00
# price to be converted:   80,00
# price to be converted:   300,00
# price to be converted:   150,00
# price to be converted:  Prix a disc.
# price to be converted:   70,00
# price to be converted:   50,00
# price to be converted:   75,00
# price to be converted:   65,00
# price to be converted:   50,00
# price to be converted:   250,00
# price to be converted:   50,00
# price to be converted:   50,00
# price to be converted:   50,00
# price to be converted:   45,00
# price to be converted:   42,00
# price to be converted:  Prix a disc.
# price to be converted:   369,00
# price to be converted:  Ne s'applique pas
# price to be converted:   500,00
# price to be converted:   50,00
# price to be converted:   175,00
# price to be converted:   1.500,00
# price to be converted:   65,00
# price to be converted:  Prix a disc.
# price to be converted:   130,00
# price to be converted:   60,00
# price to be converted:   40,00
# price to be converted:   42,00
# price to be converted:   100,00
# price to be converted:  Prix a disc.
# price to be converted:   40,00
# price to be converted:   100,00
# price to be converted:   80,00
# price to be converted:   200,00
# price to be converted:   20,00
# price to be converted:   150,00
# price to be converted:   17,00
# price to be converted:   35,00
# price to be converted:   45,00
# price to be converted:   165,00
# price to be converted:   165,00
# price to be converted:   350,00
# price to be converted:   45,00
# price to be converted:   15,00
# price to be converted:   20,00
# price to be converted:   20,00
# price to be converted:   75,00
# price to be converted:   80,00
# price to be converted:   80,00
# price to be converted:   130,00
# price to be converted:  Prix a disc.
# price to be converted:   2.499,00
# price to be converted:   120,00
# price to be converted:   1.700,00
# price to be converted:   4.900,00
# price to be converted:   369,00
# price to be converted:  Prix a disc.
# price to be converted:   1.600,00
# price to be converted:   165,00
# price to be converted:   50,00
# price to be converted:   130,00
# price to be converted:   1.000,00
# price to be converted:   35,00
# price to be converted:   120,00
# price to be converted:   70,00
# price to be converted:   55,00
# price to be converted:   70,00
# price to be converted:   250,00
# price to be converted:   140,00
# price to be converted:   70,00
# price to be converted:   50,00
# price to be converted:   68,00
# price to be converted:  Prix a disc.
# price to be converted:   67,00
# price to be converted:   15,00
# price to be converted:  Prix a disc.
# price to be converted:   50,00
# price to be converted:   2.800,00
# price to be converted:   1.090,00
# price to be converted:   100,00
# price to be converted:   75,00
# price to be converted:   95,00
# price to be converted:   45,00
# price to be converted:   40,00
# price to be converted:   20,00
# price to be converted:   1.350,00
# price to be converted:   1.999,00
# price to be converted:   60,00
# price to be converted:   650,00
# price to be converted:   800,00
# price to be converted:   250,00
# price to be converted:   200,00
# price to be converted:  Prix a disc.
# price to be converted:  Ne s'applique pas
# price to be converted:   4.900,00
# price to be converted:   35,00
# price to be converted:   150,00
# price to be converted:   85,00
# price to be converted:   1.000,00
# price to be converted:   10,00
# price to be converted:   300,00
# price to be converted:   300,00
# price to be converted:   1.900,00
# price to be converted:   25,00
# price to be converted:   40,00
# price to be converted:   1.500,00
# price to be converted:   100,00
# price to be converted:   75,00
# price to be converted:   250,00
# price to be converted:   90,00
# price to be converted:   49,99
# price to be converted:   20,00
# price to be converted:   3.000,00
# price to be converted:   100,00
# price to be converted:  Prix a disc.
# price to be converted:   20,00
# price to be converted:   25,00
# price to be converted:   35,00
# price to be converted:   50,00
# price to be converted:   120,00
# price to be converted:  Prix a disc.
# price to be converted:  Prix a disc.
# price to be converted:   960,00
# price to be converted:   60,00
# price to be converted:   140,00
# price to be converted:   80,00
# price to be converted:   50,00
# price to be converted:  Prix a disc.
# price to be converted:   120,00
# price to be converted:   165,00
# price to be converted:  Prix a disc.
# price to be converted:   10,00
# price to be converted:  Prix a disc.
# price to be converted:   1.950,00
# price to be converted:   280,00
# price to be converted:   1.100,00
# price to be converted:   30,00
# price to be converted:   200,00
# price to be converted:   220,00
# price to be converted:   30,00
# price to be converted:   65,00
# price to be converted:   400,00
# price to be converted:   360,00
# price to be converted:   45,00
# price to be converted:   170,00
# price to be converted:  Prix a disc.
# price to be converted:   40,00
# price to be converted:   35,00
# price to be converted:   120,00
# price to be converted:   75,00
# price to be converted:  Prix a disc.
# price to be converted:   40,00
# price to be converted:   30,00
# price to be converted:   1.000,00
# price to be converted:   160,00
# price to be converted:   160,00
# price to be converted:   70,00
# price to be converted:   100,00
# price to be converted:  Ne s'applique pas
# price to be converted:   50,00
# price to be converted:   100,00
# price to be converted:  Prix a disc.
# price to be converted:   50,00
# price to be converted:  Gratuit
# price to be converted:  Prix a disc.
# price to be converted:   350,00
# price to be converted:   1.250,00
# price to be converted:   100,00

# %%
len(parsed_items)
# Out:
# 380

# %%
df = pd.DataFrame(data = [x.__dict__ for x in parsed_items],
                  columns = parsed_items[0].__dict__.keys())

# %%
# let's remove the -9999 values in price

# %%
df = df[df.price != -9999]

# %%
df.price.describe()
# Out:
# count    330.000000
# mean     136.763636
# std      180.087260
# min        1.000000
# 25%       35.000000
# 50%       75.000000
# 75%      150.000000
# max      960.000000
# Name: price, dtype: float64

# %%
# strange to see a bike for 1 euro - let's set a threshold to remove these prices

# %%
df = df[df.price > 30]

# %%
df.price.describe()
# Out:
# count    249.000000
# mean     177.016064
# std      190.686767
# min       35.000000
# 25%       65.000000
# 50%      100.000000
# 75%      200.000000
# max      960.000000
# Name: price, dtype: float64
